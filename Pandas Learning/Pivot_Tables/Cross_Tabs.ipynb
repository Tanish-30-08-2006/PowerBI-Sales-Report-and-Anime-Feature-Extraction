# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

display(df)
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    670     70   John  January      Q1
# 1  2023-01-02       B   West    530     30   Mary  January      Q1
# 2  2023-01-03       C  North    580     95    Bob  January      Q1
# 3  2023-01-04       D  South    596     69  Alice  January      Q1
# 4  2023-01-05       A   East    376     52   John  January      Q1
# 5  2023-01-06       B   West    834     82   Mary  January      Q1
# 6  2023-01-07       C  North    990     92    Bob  January      Q1
# 7  2023-01-08       D  South    495     48  Alice  January      Q1
# 8  2023-01-09       A   East    700     72   John  January      Q1
# 9  2023-01-10       B   West    618     92   Mary  January      Q1
# 10 2023-01-11       C  North    891     53    Bob  January      Q1
# 11 2023-01-12       D  South    138     72  Alice  January      Q1
# 12 2023-01-13       A   East    100     76   John  January      Q1
# ...

# %%
# TO CALCULATE REGION VISE PRODUCT COUNT FOR ALL PRODUCTS ..

# group by region so index=region and product count for every region for all products so columns = products

cross_tab = pd.crosstab(df['Region'] , df['Product'],margins='True')
display(cross_tab)
# Out:
# Product  A  B  C  D  All
# Region
# East     5  0  0  0    5
# North    0  0  5  0    5
# South    0  0  0  5    5
# West     0  5  0  0    5
# All      5  5  5  5   20
